# %%
from sklearn import preprocessing, linear_model, metrics
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv("../../data/train_data.tsv", sep="\t")
test_data = pd.read_csv("../../data/test_data.tsv", sep="\t")
data = pd.read_csv("../../data/regression_data.tsv", sep="\t")

print(np.array(data.columns[3:]))
# Out:
# ['zebularine_AUC' 'azacitidine_AUC' 'nelarabine_AUC' 'myricetin_AUC'
#  'BRD-K64610608_AUC' 'ML334 diastereomer_AUC' 'BRD-K09344309_AUC'
#  'isonicotinohydroxamic acid_AUC' 'QS-11_AUC' 'brivanib_AUC' 'BRD8958_AUC'
#  'BRD-K34099515_AUC' 'A-804598_AUC' 'erismodegib_AUC' 'abiraterone_AUC'
#  'ifosfamide_AUC' 'temozolomide_AUC' 'BRD-A05715709_AUC'
#  'BRD-K48477130_AUC' 'CAY10594_AUC' 'WP1130_AUC' 'tamoxifen_AUC'
#  'importazole_AUC' 'ML006_AUC' 'AM-580_AUC' 'CD-1530_AUC'
#  'silmitasertib_AUC' 'PRL-3 inhibitor I_AUC' 'NPC-26_AUC'
#  'betulinic acid_AUC' 'salermide_AUC' 'BRD-M00053801_AUC' 'AA-COCF3_AUC'
#  'CI-976_AUC' 'pifithrin-alpha_AUC' 'purmorphamine_AUC' 'BIBR-1532_AUC'
#  'niclosamide_AUC' 'bardoxolone methyl_AUC' 'hyperforin_AUC' 'BRD4132_AUC'
#  'regorafenib_AUC' 'sorafenib_AUC' 'BRD-K51490254_AUC' 'EX-527_AUC'
#  'bendamustine_AUC' 'PYR-41_AUC' 'B02_AUC' 'ML031_AUC' 'tipifarnib-P1_AUC'
#  'BRD9876_AUC' 'parthenolide_AUC' 'tandutinib_AUC' 'CID-5951923_AUC'
#  'DBeQ_AUC' 'LE-135_AUC' 'BRD-K24690302_AUC' 'ML203_AUC'
#  'dexamethasone_AUC' 'BRD8899_AUC' 'KH-CB19_AUC' 'MK-0752_AUC'
#  'SB-431542_AUC' 'Repligen 136_AUC' 'OSI-930_AUC' 'tacrolimus_AUC'
#  'cytarabine hydrochloride_AUC' 'clofarabine_AUC' '3-Cl-AHPC_AUC'
#  'CD-437_AUC' 'gemcitabine_AUC' 'mitomycin_AUC' 'PF-184_AUC'
#  'chlorambucil_AUC' 'SN-38_AUC' 'topotecan_AUC' 'indisulam_AUC'
#  'barasertib_AUC' 'alisertib_AUC' 'bleomycin A2_AUC' 'doxorubicin_AUC'
#  'teniposide_AUC' 'etoposide_AUC' 'ruxolitinib_AUC' 'RAF265_AUC'
#  'pyrazolanthrone_AUC' 'TPCA-1_AUC' 'AZ-3146_AUC' 'Mdivi-1_AUC'
#  'elocalcitol_AUC' 'SU11274_AUC' 'BRD1835_AUC' 'SID 26681509_AUC'
#  'pevonedistat_AUC' 'BRD-K35604418_AUC' 'ETP-46464_AUC' 'NSC48300_AUC'
#  'curcumin_AUC' 'sunitinib_AUC' 'KW-2449_AUC' 'AZD4547_AUC'
#  'lenvatinib_AUC' 'pazopanib_AUC' 'tivozanib_AUC' 'axitinib_AUC'
#  'Ki8751_AUC' 'cediranib_AUC' 'MGCD-265_AUC' 'foretinib_AUC'
#  'cabozantinib_AUC' 'tamatinib_AUC' 'nintedanib_AUC' 'PIK-93_AUC'
#  'KU 0060648_AUC' 'MK-2206_AUC' 'GDC-0941_AUC' 'ZSTK474_AUC'
#  'GSK1059615_AUC' 'NVP-BEZ235_AUC' 'BYL-719_AUC' 'temsirolimus_AUC'
#  'sirolimus_AUC' 'OSI-027_AUC' 'KU-0063794_AUC' 'AZD8055_AUC'
#  'PF-573228_AUC' 'crizotinib_AUC' 'NVP-BSK805_AUC' 'TG-101348_AUC'
#  'AT7867_AUC' 'cytochalasin B_AUC' 'NVP-TAE684_AUC' 'BMS-754807_AUC'
#  'BMS-536924_AUC' 'linsitinib_AUC' 'NVP-ADW742_AUC'
#  'cyanoquinoline 11_AUC' 'austocystin D_AUC' 'olaparib_AUC' 'PI-103_AUC'
#  'triptolide_AUC' 'cucurbitacin I_AUC' 'KPT185_AUC' 'NSC632839_AUC'
#  'LRRK2-IN-1_AUC' 'JQ-1_AUC' 'GSK525762A_AUC' 'I-BET151_AUC'
#  'nutlin-3_AUC' 'HLI 373_AUC' 'serdemetan_AUC' 'necrosulfonamide_AUC'
#  'HBX-41108_AUC' 'SMER-3_AUC' 'BRD-K28456706_AUC' 'BRD-K45681478_AUC'
#  'methylstat_AUC' 'PL-DI_AUC' 'piperlongumine_AUC' 'BRD-K34222889_AUC'
#  'cerulenin_AUC' 'BRD-K26531177_AUC' 'NSC95397_AUC' 'manumycin A_AUC'
#  'CCT036477_AUC' 'PX-12_AUC' 'PRIMA-1_AUC' '968_AUC' 'ML029_AUC'
#  'AZD1480_AUC' 'RITA_AUC' 'ABT-199_AUC' 'ABT-737_AUC' 'navitoclax_AUC'
#  'R428_AUC' 'NSC23766_AUC' 'BIX-01294_AUC' 'UNC0638_AUC' 'PF-543_AUC'
#  'prochlorperazine_AUC' 'trifluoperazine_AUC' 'SCH-529074_AUC'
#  'fingolimod_AUC' 'GW-405833_AUC' 'StemRegenin 1_AUC'
#  'Bax channel blocker_AUC' 'Compound 23 citrate_AUC' 'nilotinib_AUC'
#  'masitinib_AUC' 'imatinib_AUC' 'GANT-61_AUC' 'KU-55933_AUC'
#  'KU-60019_AUC' 'BRD-K11533227_AUC'
#  'neuronal differentiation inducer III_AUC' 'BRD-K66532283_AUC'
#  'BRD-K80183349_AUC' 'tacedinaline_AUC' 'LBH-589_AUC' 'belinostat_AUC'
#  'vorinostat_AUC' 'apicidin_AUC' 'ISOX_AUC' 'entinostat_AUC' 'Merck60_AUC'
#  'BRD-K61166597_AUC' 'BRD-A86708339_AUC' 'ciclopirox_AUC' 'PAC-1_AUC'
#  'obatoclax_AUC' 'BRD-K63431240_AUC' 'sotrastaurin_AUC' 'NSC19630_AUC'
#  'PDMP_AUC' 'marinopyrrole A_AUC' 'bafilomycin A1_AUC' 'BRD-K33514849_AUC'
#  'BRD-K04800985_AUC' 'BRD-K02251932_AUC' 'BRD-K14844214_AUC'
#  'istradefylline_AUC' 'BIRB-796_AUC' 'WAY-362450_AUC' 'veliparib_AUC'
#  'BRD-K90370028_AUC' 'thalidomide_AUC' 'SZ4TA2_AUC' 'CBB-1007_AUC'
#  'ML050_AUC' 'BMS-270394_AUC' 'skepinone-L_AUC' 'MI-2_AUC'
#  'TG-100-115_AUC' 'AZD6482_AUC' 'TGX-221_AUC' 'CAL-101_AUC'
#  'pluripotin_AUC' 'saracatinib_AUC' 'dasatinib_AUC' 'WZ4002_AUC'
#  'PD 153035_AUC' 'ibrutinib_AUC' 'WZ8040_AUC' 'bosutinib_AUC'
#  'gefitinib_AUC' 'erlotinib_AUC' 'vandetanib_AUC' 'canertinib_AUC'
#  'lapatinib_AUC' 'afatinib_AUC' 'neratinib_AUC' 'BRD-K71935468_AUC'
#  'BRD-K94991378_AUC' 'VER-155008_AUC' 'IPR-456_AUC' 'BRD9647_AUC'
#  'C6-ceramide_AUC' 'VU0155056_AUC' 'Ko-143_AUC' 'L-685458_AUC' 'MI-1_AUC'
#  'UNC0321_AUC' 'fumonisin B1_AUC' 'GSK4112_AUC' 'ciclosporin_AUC'
#  'HC-067047_AUC' 'BRD-A71883111_AUC' 'tretinoin_AUC' 'Ch-55_AUC'
#  'BRD-K29086754_AUC' 'AGK-2_AUC' 'BRD-K33199242_AUC' 'BRD-K19103580_AUC'
#  'BRD-K41597374_AUC' 'BRD-K09587429_AUC' 'BRD-K52037352_AUC'
#  'BRD-K27986637_AUC' 'BRD-K48334597_AUC' 'RO4929097_AUC' 'trametinib_AUC'
#  'PD318088_AUC' 'selumetinib_AUC' 'BRD-K51831558_AUC' 'JW-55_AUC'
#  'JW-74_AUC' 'GSK2636771_AUC' 'PRIMA-1-Met_AUC' 'ML312_AUC'
#  'BRD-K16147474_AUC' 'etomoxir_AUC' 'BRD-K49290616_AUC' 'FGIN-1-27_AUC'
#  'BRD-K96431673_AUC' 'BRD-K96970199_AUC' 'BRD-K17060750_AUC'
#  'BRD-K86535717_AUC' 'BRD-K02492147_AUC' 'BRD-K75293299_AUC'
#  'sitagliptin_AUC' 'SGX-523_AUC' 'NSC30930_AUC' 'quizartinib_AUC'
#  'XL765_AUC' 'BRD-K85133207_AUC' '16-beta-bromoandrosterone_AUC'
#  'tosedostat_AUC' 'AT-406_AUC' 'birinapant_AUC' 'SRT-1720_AUC'
#  'epigallocatechin-3-monogallate_AUC' 'BRD-K13999467_AUC'
#  'BRD-A94377914_AUC' 'Compound 7d-cis_AUC' 'tipifarnib-P2_AUC'
#  'myriocin_AUC' 'avrainvillamide_AUC' 'AC55649_AUC' 'lomeguatrib_AUC'
#  'semagacestat_AUC' 'SR1001_AUC' 'BMS-195614_AUC' 'vorapaxar_AUC'
#  'blebbistatin_AUC' 'FSC231_AUC' 'ML258_AUC' 'O-6-benzylguanine_AUC'
#  'Compound 1541A_AUC' 'tubastatin A_AUC' 'CIL55_AUC' 'CAY10576_AUC'
#  'BRD-K41334119_AUC' 'BRD-K27224038_AUC' 'BRD-K84807411_AUC'
#  'BRD-K30019337_AUC' 'BRD-K78574327_AUC' 'BRD-K42260513_AUC' 'IU1_AUC'
#  'LY-2157299_AUC' 'BCL-LZH-4_AUC' 'PF-4800567 hydrochloride_AUC'
#  'pandacostat_AUC' 'BRD6340_AUC' 'BEC_AUC' 'VAF-347_AUC'
#  'BRD-K34485477_AUC' 'BRD-K37390332_AUC' 'BRD-K44224150_AUC'
#  'procarbazine_AUC' 'necrostatin-1_AUC' 'sildenafil_AUC'
#  'cyclophosphamide_AUC' 'ML083_AUC' 'necrostatin-7_AUC' 'bexarotene_AUC'
#  'SCH-79797_AUC' 'methotrexate_AUC' 'RG-108_AUC' 'GMX-1778_AUC'
#  'STF-31_AUC' 'daporinad_AUC' 'CAY10618_AUC' 'dacarbazine_AUC'
#  'fluorouracil_AUC' 'decitabine_AUC' 'PF-3758309_AUC'
#  'omacetaxine mepesuccinate_AUC' 'SNS-032_AUC' 'PHA-793887_AUC'
#  'leptomycin B_AUC' 'narciclasine_AUC' 'SR-II-138A_AUC' 'CR-1-31B_AUC'
#  'BMS-345541_AUC' 'dinaciclib_AUC' 'alvocidib_AUC' 'linifanib_AUC'
#  'MK-1775_AUC' 'AZD7762_AUC' 'N9-isopropylolomoucine_AUC'
#  'momelotinib_AUC' 'AT13387_AUC' 'SNX-2112_AUC' 'tanespimycin_AUC'
#  'NVP-231_AUC' 'ML311_AUC' 'GW-843682X_AUC' 'LY-2183240_AUC' 'BI-2536_AUC'
#  'GSK461364_AUC' 'triazolothiadiazine_AUC' 'vincristine_AUC'
#  'parbendazole_AUC' 'KX2-391_AUC' 'paclitaxel_AUC' 'SB-743921_AUC'
#  'rigosertib_AUC' 'BRD-K70511574_AUC' 'ceranib-2_AUC' 'nakiterpiosin_AUC'
#  'BRD-K66453893_AUC' 'SB-225002_AUC' 'CHM-1_AUC' 'FQI-1_AUC' 'FQI-2_AUC'
#  'ELCPK_AUC' 'docetaxel_AUC' 'tivantinib_AUC' 'YK 4-279_AUC'
#  'isoevodiamine_AUC' 'brefeldin A_AUC' 'ouabain_AUC' 'BRD-K30748066_AUC'
#  'CIL55A_AUC' 'MG-132_AUC' 'MLN2238_AUC' 'bortezomib_AUC'
#  'palmostatin B_AUC' 'pitstop2_AUC' 'darinaparsin_AUC' 'QW-BI-011_AUC'
#  'SJ-172550_AUC' 'IC-87114_AUC' 'BRD-K50799972_AUC' 'BRD-K55116708_AUC'
#  'fluvastatin_AUC' 'lovastatin_AUC' 'simvastatin_AUC' 'staurosporine_AUC'
#  'GSK-3 inhibitor IX_AUC' 'CHIR-99021_AUC' 'avicin D_AUC' 'CIL56_AUC'
#  'erastin_AUC' 'ML210_AUC' 'ML162_AUC' '1S,3R-RSL-3_AUC' 'CIL41_AUC'
#  'CIL70_AUC' 'BRD-K01737880_AUC' 'VX-680_AUC' 'isoliquiritigenin_AUC'
#  'tigecycline_AUC' 'COL-3_AUC' 'BRD-K71781559_AUC' 'MLN2480_AUC'
#  'GDC-0879_AUC' 'dabrafenib_AUC' 'PLX-4720_AUC' 'ML320_AUC'
#  'BRD-K29313308_AUC' 'BRD-K88742110_AUC' 'BRD-A02303741_AUC'
#  'NSC 74859_AUC' 'AZD7545_AUC' 'PLX-4032_AUC' 'compound 1B_AUC'
#  'BRD-K99006945_AUC' 'fulvestrant_AUC' 'SKI-II_AUC' 'cimetidine_AUC'
#  'JW-480_AUC' 'itraconazole_AUC' 'pifithrin-mu_AUC' 'SB-525334_AUC'
#  'phloretin_AUC' 'valdecoxib_AUC' 'PF-750_AUC' 'ML239_AUC' 'MST-312_AUC'
#  'TW-37_AUC' 'gossypol_AUC' 'BRD1812_AUC' 'YM-155_AUC' 'BRD-K92856060_AUC'
#  'neopeltolide_AUC' 'KHS101_AUC' 'spautin-1_AUC' 'oligomycin A_AUC'
#  'BRD-K97651142_AUC' 'SR8278_AUC' 'GSK-J4_AUC']

# %%
encoder = preprocessing.OneHotEncoder(handle_unknown='infrequent_if_exist')

#rotate this between the different drug sensitivities... a bunch of them have R^2 close to 0, which means
#that trying to discriminate by site is about as effective as just guessing the overall mean of AUCs for that
#drug regardless of site
#e.g. site isn't a good predictor for AUC... means that even in the sites where there's low AUC for a certain
#drug & cell line, high AUC cell lines get in the way

#maybe there's something else we can do: namely, we could try and find the lowest 30 AUCs in each set and then 
#verify two things 1) verify that the mean of this sample is substantially different from the mean of the overall
#(or the mean of the rest)... and 2) verify that certain sites or histologies are "enriched" relative to the majority

#a t - test, then a chi sq test?

# however, the data i'm trying to fit is going to go
#up and down sharply (namely the AUC is going to be really low, indicating sensitivity, only for a few
#drugs and only for a few cell lines within those (so, is a "good model", a "high R^2 model", supposed to
#find the sites or histologies where a particular ))
response = 'myricetin_AUC'
predictors = ['site'] #['site', 'histology']

#encoding the features: leave the response variable out, just preprocessing the features
train_raw = train_data[[*predictors, response]].dropna()
test_raw = test_data[[*predictors, response]].dropna()
print(train_raw.shape, test_raw.shape)

train_X_raw = np.array(train_raw[predictors])
test_X_raw = np.array(test_raw[predictors])

#fit encoder to categories of the training data
encoder.fit(train_X_raw)

#transform train and test data sets, introducing dummy features and new values
train_X_enc = encoder.transform(train_X_raw).toarray()
test_X_enc = encoder.transform(test_X_raw).toarray()
print(train_X_enc.shape)
print(encoder.categories_)
# Out:
# (468, 2) (153, 2)
# (468, 18)
# [array(['Ewings_sarcoma_peripheral_primitive_neuroectodermal_tumor',
#        'carcinoid_endocrine_tumor', 'carcinoma', 'chondrosarcoma',
#        'fibrosarcoma', 'glioma', 'haematopoietic_neoplasm',
#        'leiomyosarcoma', 'lymphoid_neoplasm', 'malignant_melanoma',
#        'mesothelioma', 'neuroblastoma', 'osteosarcoma',
#        'primitive_neuroectodermal_tumor_medulloblastoma',
#        'rhabdoid_tumor', 'rhabdomyosarcoma', 'sarcoma',
#        'sex_cord_stromal_tumor'], dtype=object)]

# %%
#example regression: use one of the drug AUCs as the response
train_Y = train_raw[response]

model = linear_model.LinearRegression()
model.fit(train_X_enc, train_Y)

Y_predict = model.predict(test_X_enc)
print(Y_predict)

# The coefficients
#print("Coefficients: \n", regr.coef_)
print(model.coef_)
# The mean squared error
print("Mean squared error: %.2f" % metrics.mean_squared_error(test_raw[response], Y_predict))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % metrics.r2_score(test_raw[response], Y_predict))
print("Explained variance: %.2f" % metrics.explained_variance_score(test_raw[response], Y_predict))

def total_sum_of_squares
#print("Total sum of squares: %.2f" % (test_raw[response], Y_predict))
# Out:
# [15.14329577 15.14329577 15.14329577 15.64       15.14329577 15.14329577
#  15.14329577 15.14329577 15.0947619  15.0947619  15.0947619  15.0947619
#  15.14329577 15.0947619  15.0947619  15.14329577 15.14329577 15.14329577
#  15.14329577 15.0947619  15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.0947619  15.14329577 15.0947619  15.0947619  15.14329577
#  15.0947619  15.14329577 14.75       15.0947619  15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.0947619  14.95441176 15.14329577 15.14329577 15.14329577
#  14.95441176 14.95441176 15.14329577 15.14329577 14.95441176 14.95441176
#  15.14329577 15.14329577 15.14329577 15.14329577 14.95441176 15.14329577
#  15.14329577 14.77       15.076      14.95441176 15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577 14.95441176
#  14.95441176 15.14329577 15.14329577 15.0947619  15.14329577 15.14329577
#  15.14329577 14.95441176 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.0947619  15.14329577 15.14329577 15.14329577 14.77
#  15.08249433 15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 14.39166667 15.14329577 15.14329577 15.14329577 15.0947619
#  15.0947619  15.14329577 15.14329577 15.0947619  15.14329577 15.076
#  15.14329577 15.14329577 14.95441176 14.95441176 14.95441176 15.076
#  15.14329577 15.14329577 15.14329577 14.95441176 15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577 14.95441176 15.32857143 15.14329577
#  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.0947619  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577 15.14329577 15.14329577 15.14329577
#  15.14329577 15.14329577 15.14329577]
# [-0.61249433  0.53750567  0.06080144 -0.12249433  0.80750567  0.01226757
#   0.73750567  0.55750567 -0.69082767 -0.12808257  0.24607709 -0.00649433
#  -0.18963719 -0.089161   -0.33249433 -0.31249433  0.17750567 -0.65249433]
# Mean squared error: 0.98
# Coefficient of determination: -0.02
# Coefficient of determination: 0.00
